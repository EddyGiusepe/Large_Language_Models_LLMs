# %% [markdown]
# <h1 align="center"><font color="yellow">Algumas observações: <font color="red">CHROMA</font> vs <font color="pink">FAISS</font></font></h1>

# %% [markdown]
# <font color="yellow">Data Scientist.: Dr.Eddy Giusepe Chirinos Isidro</font>

# %% [markdown]
# # CHROMA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
