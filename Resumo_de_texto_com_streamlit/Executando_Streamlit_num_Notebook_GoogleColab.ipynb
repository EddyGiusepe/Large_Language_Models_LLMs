# %% [markdown]
# <h1 align="center"><font color="yellow">Executando Streamlit num Notebook do GoogleColaboratory</font></h1>

# %% [markdown]
# <font color="yellow">Data Scientist.: Dr.Eddy Giusepe Chirinos Isidro</font>

# %% [markdown]
# <font color="orange">Neste script vamos a executar um arquivo `.py` com `streamlit`, o qual transforma o arquivo .py num Aplicativo Web. A ideia de como realizar isto no GoogleColaboratory foi baseado no [Tutorial de Manuel Romero](https://colab.research.google.com/github/mrm8488/shared_colab_notebooks/blob/master/Create_streamlit_app.ipynb#scrollTo=vWmc_s2ezvU0).</font>
#
#
# Bora começar!

# %% [markdown]
# # Instalamos as nossas bibliotecas necessárias

# %%
# !pip install streamlit
# !pip install transformers
# !pip install SentencePiece

# %% [markdown]
# # Instalamos um Túnel Local

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/drive/MyDrive/7_central_IT/3_summarization/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/drive/MyDrive/7_central_IT/3_summarization/package.json'
# npm WARN 3_summarization No description
# npm WARN 3_summarization No repository field.
# npm WARN 3_summarization No README data
# npm WARN 3_summarization No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 4.528s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %% [markdown]
# # Executamos o `streamlit` em segundo plano (no Background)

# %%
# Nota: O símbolo '>' não permite expor a porta 8501. Testa tirando esse carater '>' e vê que acontece
# !streamlit run /content/drive/MyDrive/7_central_IT/3_summarization/app.py &>/content/drive/MyDrive/7_central_IT/3_summarization/logs.txt &

# %% [markdown]
# <font color="orange">O print a seguir mostra que os dois arquivos estão na mesma pasta:</font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <font color="orange">A seguir vou expor a porta, assim: </font>

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.777s
# your url is: https://metal-cameras-agree-34-91-120-79.loca.lt
# ^C

# %%
# Eu tentei assim: ... mas não funcionou!

# %cd /content/drive/MyDrive/7_central_IT/3_summarization

# !streamlit run app.py

# %% [markdown]
# NOTA:
#
# <font color="pink">Usaremos este script devido a que os LLMs são muito pesados e desta maneira podemos Instanciar nosso `Streamlit Web`.</font>
